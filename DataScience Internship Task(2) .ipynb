# %%
Name:Sharyu Santosh Tilekar
College:Keystone School of Engineering
Class:TE(B)
Rollno:43
Assigned Task : 2

# %%
import pandas as pd

# %%
import numpy as nm

# %%
df = pd.read_csv('fb.csv')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# 1. Count how many number of posts are paid and unpaid?

# %%
df['Paid'].value_counts()
# Out:
# Paid
# 0.0    360
# 1.0    139
# Name: count, dtype: int64

# %% [markdown]
# 2. Display only Page type, Month, likes, comments and shares.

# %%
d = df[['Type','Post Month','comment','like','share']]
d
# Out:
#        Type  Post Month  comment    like  share
# 0     Photo          12        4    79.0   17.0
# 1    Status          12        5   130.0   29.0
# 2     Photo          12        0    66.0   14.0
# 3     Photo          12       58  1572.0  147.0
# 4     Photo          12       19   325.0   49.0
# ..      ...         ...      ...     ...    ...
# 495   Photo           1        5    53.0   26.0
# 496   Photo           1        0    53.0   22.0
# 497   Photo           1        4    93.0   18.0
# 498   Photo           1        7    91.0   38.0
# 499   Photo           1        0    91.0   28.0
#
# [500 rows x 5 columns]

# %% [markdown]
# 3. Find average number of likes to the post in September month.

# %%
pm = df[df['Post Month'] == 9]
pm
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 155            135700   Photo         2           9             3          7
# 156            135700   Photo         2           9             2         11
# 157            135700   Photo         3           9             2          2
# 158            135700   Photo         2           9             1         10
# 159            135617   Photo         2           9             1          3
# 160            135617   Photo         3           9             7          9
# 161            135617   Photo         2           9             7          3
# 162            135617   Photo         3           9             6         10
# 163            135617  Status         2           9             6          4
# 164            135428   Photo         1           9             5         10
# 165            135428   Photo         2           9             5          3
# ...

# %%
m = pm['like'].mean()
print("\n The average number of likes to the post in September month :",m)
# Out:
#  The average number of likes to the post in September month : 230.94444444444446

# %% [markdown]
# 4. Print the information about the posts which are links.

# %%
l = df[df['Type'] == 'Link']
l
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22             138414  Link         1          12             7         10
# 41             138895  Link         1          12             6          3
# 43             138353  Link         1          12             5          3
# 45             138353  Link         1          12             4          3
# 47             138353  Link         1          12             3          2
# 49             138353  Link         1          12             2          2
# 86             137177  Link         1          11             4          3
# 136            136393  Link         1          10             5         10
# 140            136013  Link         1          10             4          3
# 149            135713  Link         1          10             6         11
# 344            117764  Link         1           5             1          2
# ...

# %%
l.info
# Out:
# <bound method DataFrame.info of      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22             138414  Link         1          12             7         10
# 41             138895  Link         1          12             6          3
# 43             138353  Link         1          12             5          3
# 45             138353  Link         1          12             4          3
# 47             138353  Link         1          12             3          2
# 49             138353  Link         1          12             2          2
# 86             137177  Link         1          11             4          3
# 136            136393  Link         1          10             5         10
# 140            136013  Link         1          10             4          3
# 149            135713  Link         1          10             6         11
# 344            117764  Link         1           5             1          2
# ...

# %% [markdown]
# 5. How many total shares are present for the video posts?

# %%
v = df[df['Type'] == 'Video']
v
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
v1 = v['share'].sum()
print("\n Total shares are present for the video posts : ",v1)
# Out:
#  Total shares are present for the video posts :  365.0

# %% [markdown]
# 6.In which hour of the day maximum posts are posted?

# %%
ph = df[['Post Hour']]
ph
# Out:
#      Post Hour
# 0            3
# 1           10
# 2            3
# 3           10
# 4            3
# ..         ...
# 495          2
# 496          8
# 497          2
# 498         11
# 499          4
#
# [500 rows x 1 columns]

# %%
m1 = ph['Post Hour'].max()
print("\n hour of the day maximum posts are posted : ",m1)
# Out:
#  hour of the day maximum posts are posted :  23

# %% [markdown]
# 7.In which day of October, maximum number of interactions are found?

# %%
o = df[df['Post Month'] == 10]
o
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 95             137059   Photo         3          10             6         10
# 96             137059   Photo         1          10             6          3
# 97             137059   Photo         2          10             5         11
# 98             137020  Status         2          10             5          3
# 99             137020   Photo         1          10             4         10
# 100            137020   Photo         1          10             4          9
# 101            137020   Photo         2          10             4          3
# 102            137020   Photo         3          10             3         10
# 103            137020   Photo         1          10             3          4
# 104            137020   Photo         1          10             2         11
# 105            137020   Photo         1          10             2          4
# ...

# %%
i = o['Post Weekday'].max()
print("\n Maximum number of interactions are found  in day : ",i)
# Out:
#  Maximum number of interactions are found  in day :  7

# %% [markdown]
# 8.Print the information of the posts where likes are above 200 and shares are above 30.

# %%
p = df[(df['like'] > 200) & (df['share'] > 30 )]

# %%
p
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 26             138458  Status         2          12             5         11
# 28             138895   Photo         2          12             5          3
# 38             138895  Status         2          12             7          9
# ..                ...     ...       ...         ...           ...        ...
# 464             92079   Photo         1           2             6         13
# 468             91651   Photo         1           2             4         12
# 476             86909   Photo         1           1             6         10
# 480             86909   Photo         2           1             4         11
# 488             85979   Photo         3           1             7         10
#
# ...

# %%
p.info
# Out:
# <bound method DataFrame.info of      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 26             138458  Status         2          12             5         11
# 28             138895   Photo         2          12             5          3
# 38             138895  Status         2          12             7          9
# ..                ...     ...       ...         ...           ...        ...
# 464             92079   Photo         1           2             6         13
# 468             91651   Photo         1           2             4         12
# 476             86909   Photo         1           1             6         10
# 480             86909   Photo         2           1             4         11
# 488             85979   Photo         3           1             7         10
#
# ...

# %% [markdown]
# 9.Which kind of posts are posted maximum number of times in November month?

# %%
n = df[df['Post Month'] == 11]
n
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 50            138353   Photo         2          11             1          9
# 51            138329   Photo         1          11             1          3
# 52            138329   Photo         1          11             7          9
# 53            138329   Photo         1          11             7          3
# 54            138329   Photo         1          11             6         10
# 55            138329   Video         1          11             6          2
# 56            138329   Photo         1          11             5         11
# 57            138329   Photo         1          11             5          3
# 58            138329   Photo         1          11             4         10
# 59            138329   Photo         1          11             4          3
# 60            138185   Photo         1          11             3         11
# ...

# %%
t = n['Type']

# %%
t
# Out:
# 50     Photo
# 51     Photo
# 52     Photo
# 53     Photo
# 54     Photo
# 55     Video
# 56     Photo
# 57     Photo
# 58     Photo
# 59     Photo
# 60     Photo
# 61     Photo
# 62     Photo
# 63     Photo
# 64     Photo
# 65     Photo
# 66     Photo
# 67     Photo
# 68     Photo
# 69     Photo
# 70     Photo
# 71     Video
# 72    Status
# 73     Photo
# 74     Video
# 75     Photo
# 76     Photo
# 77     Photo
# 78     Photo
# 79     Photo
# 80    Status
# 81     Photo
# 82     Photo
# 83     Photo
# 84    Status
# 85     Photo
# 86      Link
# 87     Photo
# 88     Photo
# 89     Photo
# 90     Photo
# 91     Photo
# 92     Photo
# 93     Photo
# 94     Photo
# Name: Type, dtype: object

# %%
t = n['Type'].value_counts()
t
# Out:
# Type
# Photo     38
# Video      3
# Status     3
# Link       1
# Name: count, dtype: int64

# %%
p = t.max()
print('\n kind of posts are posted maximum number of times in November month is photos : ' , p)
# Out:
#  kind of posts are posted maximum number of times in November month is photos :  38

# %% [markdown]
# 10.Find average and median of interactions for the paid (1) posts.

# %%
p1 = df[df['Paid'] == 1 ]

# %%
p1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441  Photo         2          12             2         10
# 6              139441  Photo         3          12             1          3
# 7              139441  Photo         3          12             7          9
# 14             138414  Photo         2          12             4          5
# 17             138414  Photo         1          12             2         12
# ..                ...    ...       ...         ...           ...        ...
# 473             91116  Photo         3           2             2          4
# 475             86909  Photo         3           1             6         16
# 476             86909  Photo         1           1             6         10
# 481             86491   Link         1           1             4          4
# 491             85979  Photo         3           1             6          3
#
# ...

# %%
m2 = p1['Total Interactions'].median()
print('\n median of interactions for the paid (1) posts : ' , m2)
# Out:
#  median of interactions for the paid (1) posts :  158.0

# %%
m3 = p1['Total Interactions'].mean()
print('\n average of interactions for the paid (1) posts : ' , m3)
# Out:
#  average of interactions for the paid (1) posts :  278.23021582733816

# %% [markdown]
# 11. Plot monthwise count of the posts.

# %%
import matplotlib.pyplot as plt
x=df['Post Month'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# 12. Find the average of all reactions (like, comment and shares) of type ‘status’.

# %%
s = df[df['Type'] == 'Status']
s
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
s1 = s[['comment', 'like','share']]
s1
# Out:
#      comment   like  share
# 1          5  130.0   29.0
# 5          1  152.0   33.0
# 8          0  161.0   31.0
# 10         0  233.0   19.0
# 15         4   86.0   18.0
# 18         4   54.0   17.0
# 24         3   99.0   19.0
# 25         0   88.0   18.0
# 26        10  412.0   72.0
# 38        11  227.0   31.0
# 40         7  216.0   39.0
# 46         4  174.0   36.0
# 72         3  226.0   44.0
# 80         2   86.0   13.0
# 84         2   99.0   16.0
# 98         7  310.0   61.0
# 107       17  193.0   28.0
# 109        4  217.0   50.0
# 121        6  186.0   40.0
# 138        0  129.0   25.0
# 141        2  227.0   36.0
# 142       60  859.0   90.0
# 148        3  148.0   28.0
# 163        4  243.0   41.0
# 172       38  163.0   27.0
# 175        2  165.0   22.0
# 180       20  150.0   29.0
# 202        2   53.0   15.0
# 217       41   15.0    1.0
# 222        1   74.0   11.0
# 223       18  332.0   54.0
# 225        9   95.0   17.0
# 232        6   14.0    1.0
# ...

# %%
L = s1['like'].mean()
print('\n average of like reactions : ' , L)
# Out:
#  average of like reactions :  176.7111111111111

# %%
C = s1['comment'].mean()
print('\n average of comments reactions : ' , C)
# Out:
#  average of comments reactions :  8.911111111111111

# %%
S = s1['like'].mean()
print('\n average of share reactions : ' , S)
# Out:
#  average of share reactions :  176.7111111111111

# %% [markdown]
# 13. Plot the monthwise total count of shares for photo posts.

# %%
pp = df[df['Type'] == 'Photo']
pp
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
pms =df[['Post Month','share']]
pms
# Out:
#      Post Month  share
# 0            12   17.0
# 1            12   29.0
# 2            12   14.0
# 3            12  147.0
# 4            12   49.0
# ..          ...    ...
# 495           1   26.0
# 496           1   22.0
# 497           1   18.0
# 498           1   38.0
# 499           1   28.0
#
# [500 rows x 2 columns]

# %%
t2 = df[df['Type'] == 'photo']
df.groupby('Post Month')['share'].sum().plot(kind='bar')
plt.xlabel('Post Month')
plt.ylabel('share')
plt.title('Monthwise total count of shares for photo posts')
plt.show()

# %% [markdown]
# 14. Print the information of posts where no comments are posted. Which kind of posts are
# having highest no comments?

# %%
c = df[df['comment'] == 0 ]

# %%
c
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 2              139441   Photo         3          12             3          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 481             86491    Link         1           1             4          4
# 485             86491    Link         1           1             2          2
# 492             85979    Link         1           1             5         11
# 496             81370   Photo         2           1             5          8
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
c.info
# Out:
# <bound method DataFrame.info of      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 2              139441   Photo         3          12             3          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 481             86491    Link         1           1             4          4
# 485             86491    Link         1           1             2          2
# 492             85979    Link         1           1             5         11
# 496             81370   Photo         2           1             5          8
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
c1 = c['Type'].max()
print('\n kind of posts are having highest no comments : ' , c1)
# Out:
#  kind of posts are having highest no comments :  Status

# %% [markdown]
# 15) Sort all the posts in descending order of total interactions group by type during August –
# December.

# %%
z = df[(df['Post Month'] > 7) & (df['Post Month'] == 12)]
df.sort_values(by= "Total Interactions", ascending=False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 168            135428  Photo         1           9             3         10
# 460             92507  Photo         3           2             1         13
# 349            117764  Photo         3           5             5         13
# ..                ...    ...       ...         ...           ...        ...
# 100            137020  Photo         1          10             4          9
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
# 441             98195  Photo         1           3             5          4
# 76             137893  Photo         1          11             3          2
#
# ...
