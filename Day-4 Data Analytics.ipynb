# %% [markdown]
# #Name:-Sharyu Santosh Tilekar
# #College:Keystone School of Engineering
# #Class:TE(B)
# #Roll No:43

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
x = np.array([12,23,34,45,49,56,61,68,71,78])
y = np.array([23,31,38,43,49,56,65,71,79,85])
z = np.array([21,32,43,54,94,65,16,86,17,87])

# %% [markdown]
# #Line Plot

# %%
plt.plot(x, y);

# %%
plt.plot(x, z);

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, y);

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, z);

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = 'o', color = 'red' , mfc= 'b');

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = 'o', color = 'red' , mfc= 'b',ls='--',ms = 5);

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = 'o', color = 'red' , mfc= 'b',ls='--',ms = 5);

plt.grid()
# marker => <,>,^,O.*,H

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, z, marker = 'o', color = 'green' , mfc= 'b',ls='--',ms = 5);

plt.grid()
# marker => <,>,^,O.*,H

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, z, marker = '>', color = 'green' , mfc= 'b',ls='--',ms = 5);

plt.grid()
# marker => <,>,^,O.*,H

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, z, marker = '<', color = 'green' , mfc= 'b',ls='--',ms = 5);

plt.grid()

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, z, marker = '^', color = 'green' , mfc= 'b',ls='--',ms = 5);

plt.grid()

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, z, marker = 'H', color = 'green' , mfc= 'b',ls='--',ms = 5);

plt.grid()

# %%
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = '*', color = 'red' , mfc = 'black',ls='--',ms = 7);
plt.plot(x, z, marker = 'o', color = 'green' , mfc = 'blue',ls='--',ms = 5);
plt.grid()

# %%
plt.subplot(2,2,1)
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = '*', color = 'red' , mfc = 'black',ls='--',ms = 7);
plt.grid()

plt.subplot(2,2,2)
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = '*', color = 'red' , mfc = 'black',ls='--',ms = 7);
plt.plot(x, z, marker = 'o', color = 'green' , mfc = 'blue',ls='--',ms = 5);
plt.grid()

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = '*', color = 'red' , mfc = 'black',ls='--',ms = 7);
plt.grid()

plt.subplot(2,2,2)
plt.title('Line Plot')
plt.xlabel('Frist Value')
plt.ylabel('Second Value')
plt.plot(x, z, marker = 'o', color = 'green' , mfc = 'blue',ls='--',ms = 5);
plt.grid()

# %% [markdown]
# #Bar Graph

# %%
students = [56,65,46,51,61]
courses = ['Java','Python','C','Cpp','R']
plt.bar(courses,students);

# %%
plt.title('Students Data')
plt.xlabel('students')
plt.ylabel('courses')
plt.bar(courses,students,color ='red', edgecolor = 'black',width=0.6,linewidth =3 ,alpha=0.3);

# %% [markdown]
# #Scatter Plot

# %%
plt.scatter(x,y, marker='H');
plt.grid()

# %%
plt.title('Students Data')
plt.xlabel('students')
plt.ylabel('courses')
plt.scatter(x,y);

# %% [markdown]
# #Pie Chart

# %%
plt.title('Pie Chart')
plt.pie(students,labels = courses);

# %%
plt.title('Pie Chart')
plt.pie(students,labels = courses ,autopct='%.2f%%',shadow=True);

# %%
plt.title('Pie Chart')
plt.pie(students,labels = courses ,autopct='%.2f%%',shadow=True,radius=0.8,labeldistance=1.2);

# %%
plt.title('Pie Chart')
plt.pie(students,labels = courses ,autopct='%0.3f%%',radius=0.8,labeldistance=1.2,
        colors=['blue','yellow','green','violet','red'],startangle=30,explode = [0,0,0.2,0,0.1])
# Out:
# ([<matplotlib.patches.Wedge at 0x15e27eed710>,
# ...
#  [Text(0.38849112353094223, 0.877880770342799, 'Java'),
#   Text(-0.7785580654022095, 0.5616469877041705, 'Python'),
#   Text(-0.9407575564602706, -0.6786569236093453, 'C'),
#   Text(0.14002593205393093, -0.9497329826600884, 'Cpp'),
#   Text(1.0459026450171112, -0.1723010654238996, 'R')],
#  [Text(0.19424556176547111, 0.4389403851713995, '20.072%'),
#   Text(-0.38927903270110475, 0.28082349385208527, '23.297%'),
#   Text(-0.5514785675801587, -0.3978333690123748, '16.487%'),
#   Text(0.07001296602696547, -0.4748664913300442, '18.280%'),
#   Text(0.572286352933891, -0.09427794145836017, '21.864%')])

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title('Students Data')
plt.xlabel('students')
plt.ylabel('courses')
plt.plot(courses,students, marker = '*', color = 'red' , mfc = 'black',ls='--',ms = 7);
plt.grid()

plt.subplot(2,2,2)
plt.title('Students Data')
plt.xlabel('students')
plt.ylabel('courses')
plt.plot(courses,students, marker = '*', color = 'red' , mfc = 'black',ls='--',ms = 7);
plt.grid()

plt.subplot(2,2,3)
plt.title('Students Data')
plt.xlabel('students')
plt.ylabel('courses')
plt.bar(courses,students,color ='red', edgecolor = 'black',width=0.6,linewidth =3 ,alpha=0.3);

plt.subplot(2,2,4)
plt.title('Pie Chart')
plt.pie(students,labels = courses ,autopct='%0.3f%%',radius=0.8,labeldistance=1.2,
        colors=['blue','yellow','green','violet','red'],startangle=30,explode = [0,0,0.2,0,0.1])

plt.savefig('My Graphs')

# %% [markdown]
# #Box Plot

# %%
marks = [67,63,70,75,72,56,51,21,95,200]

# %%
plt.boxplot(marks);

# %%
q3 = np.percentile(marks,75)
q1 = np.percentile(marks,25)

# %%
q3,q1
# Out:
# (74.25, 57.75)

# %%
iqr = q3 - q1
iqr #interquartile range
# Out:
# 16.5

# %%
#lower Bound
lb = q1 - 1.5 * iqr

#Upper Bound
up = q3 + 1.5 * iqr

# %%
lb,up
# Out:
# (33.0, 99.0)

# %% [markdown]
# #On Datasets

# %%
a = pd.read_csv('student.csv')

# %%
a
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
plt.title('student data')
plt.xlabel('marks')
plt.ylabel('roll')
plt.bar(a['marks'], a['roll'], color = ['cyan','orange','blue','red','pink','yellow','purple','violet','skyblue','green'] )
# Out:
# <BarContainer object of 10 artists>

# %%
plt.title('student data')
plt.xlabel('marks')
plt.ylabel('roll')
mycolor = ['cyan','orange','blue','red','pink','yellow','purple','violet','skyblue','green'] 
plt.barh(a['marks'], a['roll'], color= mycolor,linewidth=3,edgecolor='black' )
# Out:
# <BarContainer object of 10 artists>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('_mpl-gallery-nogrid')
plt.xlabel('marks')
plt.ylabel('roll')
plt.barh(a['marks'], a['roll'])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.style.use( 'seaborn-v0_8-colorblind',)
plt.xlabel('marks')
plt.ylabel('roll')
plt.barh(a['marks'], a['name'])
# Out:
# <BarContainer object of 10 artists>

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,hue='time')
plt.show()

# %% [markdown]
# #Histogram

# %%
plt.xlabel('Tip Amount')
plt.ylabel('Frequency')
sns.histplot(tips['tip'],kde=True)
plt.show()

# %%
plt.title('Outliers in tip')
plt.xlabel('Day')
plt.ylabel('tip')
sns.boxenplot(x='day',y='tip',data=tips)
plt.show()

# %%
sns.pairplot(tips,hue = 'smoker');
plt.show()
